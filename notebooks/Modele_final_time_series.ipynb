# %% [markdown]
# <a href="https://colab.research.google.com/github/terencebeauj/mle_project/blob/master/Modele_final_time_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import SimpleRNN, Dense, Input, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.optimizers import SGD, Adam

# %%
cd /content/drive/MyDrive/Colab_Notebooks/Projet/Dossier_final/data
# Out:
# /content/drive/MyDrive/Colab_Notebooks/Projet/Dossier_final/data

# %%
df = pd.read_csv("./final_preprocess_df.csv", index_col=0, sep=",", encoding="utf8")

df["dateT_E"] = pd.to_datetime(df.dateT_E)
df["date"] = pd.to_datetime(df.date)

df.head()
# Out:
#               dateT_E              dateT_S  ...  ferie_chome school vacation
# 0 2020-06-29 18:07:00  2020-06-30 20:50:00  ...      travail             non
# 1 2019-10-05 08:05:00  2019-10-06 10:45:00  ...      travail             non
# 2 2017-01-21 20:30:00  2017-01-22 23:00:00  ...      travail             oui
# 3 2017-02-27 13:45:00  2017-02-28 16:00:00  ...      travail             non
# 4 2017-01-05 12:40:00  2017-01-06 14:49:00  ...        FERIE             non
#
# [5 rows x 27 columns]

# %% [markdown]
# On classe les données dans l'ordre pour le modele de time series

# %%
df = df.sort_values("dateT_E")

# %%
df.tail()
# Out:
#                    dateT_E              dateT_S  ...  ferie_chome school vacation
# 129792 2021-04-30 23:03:00  2021-05-01 00:39:00  ...      travail             non
# 179892 2021-04-30 23:06:00  2021-04-30 23:51:00  ...      travail             non
# 77097  2021-04-30 23:25:00  2021-05-01 02:27:00  ...      travail             non
# 150428 2021-04-30 23:51:00  2021-05-01 01:04:00  ...      travail             non
# 172416 2021-04-30 23:53:00  2021-05-01 00:45:00  ...      travail             non
#
# [5 rows x 27 columns]

# %% [markdown]
# On crée une série pour passer au modele

# %%
time_serie = df.groupby(["date"]).count().code
time_serie.head(20)
# Out:
# date
# 2016-01-01    174
# 2016-01-02    157
# 2016-01-03    129
# 2016-01-04    142
# 2016-01-05    133
# 2016-01-06    129
# 2016-01-07    134
# 2016-01-08    135
# 2016-01-09    144
# 2016-01-10    138
# 2016-01-11    129
# 2016-01-12    138
# 2016-01-13    113
# 2016-01-14    114
# 2016-01-15    130
# 2016-01-16    126
# 2016-01-17    140
# 2016-01-18    130
# 2016-01-19    106
# 2016-01-20    127
# Name: code, dtype: int64

# %%
time_serie.tail()
# Out:
# date
# 2021-04-26    134
# 2021-04-27    102
# 2021-04-28    114
# 2021-04-29    111
# 2021-04-30    129
# Name: code, dtype: int64

# %% [markdown]
# On crée 2 série différentes, une avant covid, l'autre apres.

# %%
time_serie_before_covid = time_serie.loc[:"2019-12-31"]
time_serie_covid = time_serie.loc["2020-01-01":]

time_serie_before_covid.tail()
# Out:
# date
# 2019-12-27    133
# 2019-12-28    123
# 2019-12-29    119
# 2019-12-30    141
# 2019-12-31    107
# Name: code, dtype: int64

# %%
time_serie_covid.tail()
# Out:
# date
# 2021-04-26    134
# 2021-04-27    102
# 2021-04-28    114
# 2021-04-29    111
# 2021-04-30    129
# Name: code, dtype: int64

# %% [markdown]
# **Étude avant le Covid**

# %% [markdown]
# On préprocesse les données avamt de les passer au modele, car les modeles de time series acceptent en entier des vecteurs en 3D.
#
# On prendre un  T = 7, c-à-d qu'on se servira des données des 7 jours antécédents pour prédire la valeur de flux du jour suivant.

# %%
T = 7
D = 1
X = []
Y = []
for t in range(len(time_serie_before_covid) - T):
  x = time_serie_before_covid[t:t+T]
  X.append(x)
  y = time_serie_before_covid[t+T]
  Y.append(y)

X = np.array(X).reshape(-1, T, 1)
Y = np.array(Y)
N = len(X)
print(X.shape, Y.shape)
# Out:
# (1454, 7, 1) (1454,)

# %% [markdown]
# Pour le modele, on utilise une cellule RNN et un neurone dans la couche de sortie avec une fonction d'activation linéaire.
#
# On utilisera l'optimiseur Adam avec la fonction de loss MSE.
#
# On prendra la moitié des données pour l'entraînement, et la moitié restante pour les tests.

# %%
i = Input(shape=(T, 1))
x = SimpleRNN(5, activation=LeakyReLU())(i)
x = Dense(1)(x)

model = Model(i, x)
model.compile(optimizer=Adam(lr=0.01),
              loss="mse",
              metrics=["mape"])

history = model.fit(X[:-N//2],
                    Y[:-N//2],
                    validation_data=(X[-N//2:], Y[-N//2:]),
                    epochs=50)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 2s 27ms/step - loss: 3604.1921 - mape: 38.3590 - val_loss: 410.2462 - val_mape: 12.3695
# Epoch 2/50
# 23/23 [==============================] - 0s 8ms/step - loss: 492.4644 - mape: 13.3872 - val_loss: 403.9155 - val_mape: 12.4761
# Epoch 3/50
# 23/23 [==============================] - 0s 10ms/step - loss: 473.8448 - mape: 13.7033 - val_loss: 394.7231 - val_mape: 12.0257
# Epoch 4/50
# 23/23 [==============================] - 0s 9ms/step - loss: 455.4617 - mape: 13.1897 - val_loss: 372.3287 - val_mape: 11.7804
# Epoch 5/50
# 23/23 [==============================] - 0s 9ms/step - loss: 429.5140 - mape: 12.6107 - val_loss: 363.3708 - val_mape: 11.7041
# Epoch 6/50
# 23/23 [==============================] - 0s 10ms/step - loss: 433.0113 - mape: 12.8667 - val_loss: 353.4065 - val_mape: 11.5479
# Epoch 7/50
# 23/23 [==============================] - 0s 9ms/step - loss: 415.4318 - mape: 12.6756 - val_loss: 316.6292 - val_mape: 10.9693
# Epoch 8/50
# 23/23 [==============================] - 0s 9ms/step - loss: 328.5873 - mape: 11.3131 - val_loss: 311.5563 - val_mape: 11.4798
# Epoch 9/50
# 23/23 [==============================] - 0s 9ms/step - loss: 304.7826 - mape: 10.9460 - val_loss: 278.6139 - val_mape: 9.8940
# Epoch 10/50
# 23/23 [==============================] - 0s 9ms/step - loss: 319.1417 - mape: 10.9169 - val_loss: 291.0924 - val_mape: 10.9954
# Epoch 11/50
# 23/23 [==============================] - 0s 9ms/step - loss: 305.8406 - mape: 10.9148 - val_loss: 251.5586 - val_mape: 9.6828
# Epoch 12/50
# 23/23 [==============================] - 0s 9ms/step - loss: 321.3251 - mape: 10.7897 - val_loss: 251.8347 - val_mape: 9.7949
# Epoch 13/50
# 23/23 [==============================] - 0s 9ms/step - loss: 279.3792 - mape: 10.2923 - val_loss: 248.4323 - val_mape: 9.6089
# Epoch 14/50
# 23/23 [==============================] - 0s 10ms/step - loss: 251.0102 - mape: 9.8679 - val_loss: 253.7651 - val_mape: 10.0244
# Epoch 15/50
# 23/23 [==============================] - 0s 10ms/step - loss: 302.7778 - mape: 11.1835 - val_loss: 243.6022 - val_mape: 9.5615
# Epoch 16/50
# Epoch 38/50
# 23/23 [==============================] - 0s 9ms/step - loss: 264.0313 - mape: 10.2592 - val_loss: 236.4690 - val_mape: 9.3285
# Epoch 39/50
# 23/23 [==============================] - 0s 9ms/step - loss: 257.4508 - mape: 9.7659 - val_loss: 238.8054 - val_mape: 9.5530
# Epoch 40/50
# 23/23 [==============================] - 0s 10ms/step - loss: 266.7109 - mape: 10.0832 - val_loss: 237.0346 - val_mape: 9.3683
# Epoch 41/50
# 23/23 [==============================] - 0s 10ms/step - loss: 255.7717 - mape: 9.7882 - val_loss: 269.2642 - val_mape: 9.6480
# Epoch 42/50
# 23/23 [==============================] - 0s 10ms/step - loss: 307.7173 - mape: 10.5016 - val_loss: 263.1393 - val_mape: 10.3066
# Epoch 43/50
# 23/23 [==============================] - 0s 10ms/step - loss: 292.3556 - mape: 10.7160 - val_loss: 258.3789 - val_mape: 10.1660
# Epoch 44/50
# 23/23 [==============================] - 0s 11ms/step - loss: 285.8938 - mape: 10.6058 - val_loss: 236.9599 - val_mape: 9.4799
# Epoch 45/50
# 23/23 [==============================] - 0s 9ms/step - loss: 264.0177 - mape: 10.1324 - val_loss: 269.7480 - val_mape: 9.6524
# Epoch 46/50
# 23/23 [==============================] - 0s 10ms/step - loss: 283.8373 - mape: 10.4481 - val_loss: 238.9359 - val_mape: 9.5639
# Epoch 47/50
# 23/23 [==============================] - 0s 11ms/step - loss: 233.1207 - mape: 9.5810 - val_loss: 237.9554 - val_mape: 9.5265
# Epoch 48/50
# 23/23 [==============================] - 0s 10ms/step - loss: 297.4513 - mape: 10.7989 - val_loss: 253.7856 - val_mape: 9.4398
# Epoch 49/50
# 23/23 [==============================] - 0s 11ms/step - loss: 280.3175 - mape: 10.2286 - val_loss: 235.8551 - val_mape: 9.3317
# Epoch 50/50
# 23/23 [==============================] - 0s 10ms/step - loss: 261.6794 - mape: 10.1854 - val_loss: 261.4766 - val_mape: 10.2551

# %% [markdown]
# On peut constater que les loss d'entraînement et de validation convergent vers une asymptote horizontale. C'est un bon signe pour notre modele, notamment par rapport à l'overfitting.

# %%
plt.plot(history.history["loss"], label="loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.legend()
plt.title("loss/epoch")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show();

# %%
plt.plot(history.history["mape"], label="mape")
plt.plot(history.history["val_mape"], label="val_mape")
plt.legend()
plt.title("mape/epoch")
plt.xlabel("epochs")
plt.ylabel("mape")
plt.show()

# %%
results = model.evaluate(X[-N//2:], Y[-N//2:])
print(f"MAPE: {results[1]:.2f}")
# Out:
# 23/23 [==============================] - 0s 2ms/step - loss: 261.4766 - mape: 10.2551
# MAPE: 10.26

# %% [markdown]
# On peut visualiser ci-dessous les courbes des valeurs réelles et des prédictions.
#
# Mis à part les valeurs présentes aux pics, on peut constater que le modele approxime bien les données, ce qui correspond bien avec notre MAPE de 10.26%.

# %%
X_test = X[-N//2:]
y_pred = model.predict(X_test)

plt.figure(figsize=(20, 10))
plt.plot(list(time_serie_before_covid.index[-N//2:]), Y[-N//2:], label="valeurs réelles")
plt.plot(list(time_serie_before_covid.index[-N//2:]),y_pred, label="valeurs prédites")
plt.legend()
plt.title("Prédictions vs valeurs réelles des flux de patients en fonction du temps (avant le Covid)")
plt.xlabel("dates")
plt.ylabel("nombre de patients")
plt.show();

# %% [markdown]
# **Étude durant le COVID**

# %% [markdown]
# On prépare les matrices pour le modele.

# %%
T = 7
D = 1
X = []
Y = []
for t in range(len(time_serie_covid) - T):
  x = time_serie_covid[t:t+T]
  X.append(x)
  y = time_serie_covid[t+T]
  Y.append(y)

X = np.array(X).reshape(-1, T, 1)
Y = np.array(Y)
N = len(X)
print(X.shape, Y.shape)
# Out:
# (479, 7, 1) (479,)

# %% [markdown]
# On utilise le même modele avec le même optimiseur et une métrique identique.

# %%
i = Input(shape=(T, 1))
x = SimpleRNN(5, activation=LeakyReLU())(i)
x = Dense(1)(x)

model = Model(i, x)
model.compile(optimizer=Adam(lr=0.01),
              loss="mse",
              metrics=["mape"])

history = model.fit(X[:-N//2],
                    Y[:-N//2],
                    validation_data=(X[-N//2:], Y[-N//2:]),
                    epochs=50)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 1s 37ms/step - loss: 24660.4434 - mape: 128.7217 - val_loss: 22740.3887 - val_mape: 119.2194
# Epoch 2/50
# 8/8 [==============================] - 0s 12ms/step - loss: 20046.0931 - mape: 116.5428 - val_loss: 18788.9941 - val_mape: 108.1266
# Epoch 3/50
# 8/8 [==============================] - 0s 15ms/step - loss: 15673.8901 - mape: 105.5363 - val_loss: 15033.0928 - val_mape: 96.4096
# Epoch 4/50
# 8/8 [==============================] - 0s 12ms/step - loss: 12798.1331 - mape: 93.2164 - val_loss: 10958.7432 - val_mape: 81.8274
# Epoch 5/50
# 8/8 [==============================] - 0s 12ms/step - loss: 8927.8252 - mape: 77.4470 - val_loss: 6222.5654 - val_mape: 60.6502
# Epoch 6/50
# 8/8 [==============================] - 0s 12ms/step - loss: 4441.4191 - mape: 53.4996 - val_loss: 1415.5409 - val_mape: 25.5981
# Epoch 7/50
# 8/8 [==============================] - 0s 12ms/step - loss: 607.6332 - mape: 17.1431 - val_loss: 934.0272 - val_mape: 22.3247
# Epoch 8/50
# 8/8 [==============================] - 0s 12ms/step - loss: 892.7120 - mape: 23.4256 - val_loss: 513.0917 - val_mape: 15.3258
# Epoch 9/50
# 8/8 [==============================] - 0s 12ms/step - loss: 360.8813 - mape: 13.8363 - val_loss: 482.4102 - val_mape: 13.3594
# Epoch 10/50
# 8/8 [==============================] - 0s 11ms/step - loss: 391.2582 - mape: 13.0250 - val_loss: 423.0165 - val_mape: 12.4581
# Epoch 11/50
# 8/8 [==============================] - 0s 12ms/step - loss: 319.0401 - mape: 11.8802 - val_loss: 344.0065 - val_mape: 11.8968
# Epoch 12/50
# 8/8 [==============================] - 0s 12ms/step - loss: 284.0379 - mape: 12.2713 - val_loss: 340.7373 - val_mape: 11.8287
# Epoch 13/50
# 8/8 [==============================] - 0s 14ms/step - loss: 259.5668 - mape: 11.3284 - val_loss: 326.2295 - val_mape: 11.1842
# Epoch 14/50
# 8/8 [==============================] - 0s 12ms/step - loss: 295.1802 - mape: 12.0195 - val_loss: 326.6751 - val_mape: 11.1379
# Epoch 15/50
# 8/8 [==============================] - 0s 12ms/step - loss: 252.1314 - mape: 11.2180 - val_loss: 322.5228 - val_mape: 11.2100
# Epoch 16/50
# 8/8 [==============================] - 0s 12ms/step - loss: 238.8507 - mape: 10.9719 - val_loss: 316.7162 - val_mape: 11.0107
# Epoch 38/50
# 8/8 [==============================] - 0s 12ms/step - loss: 246.5250 - mape: 10.8694 - val_loss: 319.2330 - val_mape: 11.2473
# Epoch 39/50
# 8/8 [==============================] - 0s 12ms/step - loss: 269.0472 - mape: 11.7311 - val_loss: 317.8248 - val_mape: 10.9582
# Epoch 40/50
# 8/8 [==============================] - 0s 12ms/step - loss: 249.0480 - mape: 11.3077 - val_loss: 317.0580 - val_mape: 11.1502
# Epoch 41/50
# 8/8 [==============================] - 0s 11ms/step - loss: 280.7386 - mape: 11.6506 - val_loss: 315.8060 - val_mape: 11.0073
# Epoch 42/50
# 8/8 [==============================] - 0s 12ms/step - loss: 249.6199 - mape: 10.9059 - val_loss: 317.6867 - val_mape: 10.9395
# Epoch 43/50
# 8/8 [==============================] - 0s 12ms/step - loss: 233.1221 - mape: 10.8677 - val_loss: 315.6238 - val_mape: 11.0808
# Epoch 44/50
# 8/8 [==============================] - 0s 13ms/step - loss: 233.0514 - mape: 10.8497 - val_loss: 316.4860 - val_mape: 11.1443
# Epoch 45/50
# 8/8 [==============================] - 0s 11ms/step - loss: 259.5722 - mape: 11.3059 - val_loss: 315.8332 - val_mape: 10.9473
# Epoch 46/50
# 8/8 [==============================] - 0s 15ms/step - loss: 276.1283 - mape: 11.6702 - val_loss: 314.8268 - val_mape: 11.0476
# Epoch 47/50
# 8/8 [==============================] - 0s 11ms/step - loss: 248.5835 - mape: 10.8243 - val_loss: 314.6034 - val_mape: 11.0387
# Epoch 48/50
# 8/8 [==============================] - 0s 12ms/step - loss: 238.8221 - mape: 10.9550 - val_loss: 314.3384 - val_mape: 10.9828
# Epoch 49/50
# 8/8 [==============================] - 0s 15ms/step - loss: 262.1462 - mape: 11.3319 - val_loss: 314.8567 - val_mape: 11.0850
# Epoch 50/50
# 8/8 [==============================] - 0s 11ms/step - loss: 219.1310 - mape: 10.4966 - val_loss: 315.2382 - val_mape: 10.9146

# %% [markdown]
# On a une bonne convergence des fonctions de loss, le modele a donc moins l'occasion d'overfitter.

# %%
plt.plot(history.history["loss"], label="loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.legend()
plt.title("loss/epoch")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show();

# %%
plt.plot(history.history["mape"], label="mape")
plt.plot(history.history["val_mape"], label="val_mape")
plt.legend()
plt.title("mape/epoch")
plt.xlabel("epochs")
plt.ylabel("mape")
plt.show()

# %% [markdown]
# On a une MAPE de 10.91%

# %%
results = model.evaluate(X[-N//2:], Y[-N//2:])
print(f"MAPE: {results[1]:.2f}")
# Out:
# 8/8 [==============================] - 0s 2ms/step - loss: 315.2382 - mape: 10.9146
# MAPE: 10.91

# %% [markdown]
# On peut voir ci-dessous les courbes des prédictions et des valeurs réelles

# %%
X_test = X[-N//2:]
y_pred = model.predict(X_test)

plt.figure(figsize=(20, 10))

plt.plot(list(time_serie_covid.index[-N//2:]), Y[-N//2:], label="valeurs réelles")
plt.plot(list(time_serie_covid.index[-N//2:]),y_pred, label="valeurs prédites")
plt.legend()
plt.title("Prédictions vs valeurs réelles des flux de patients en fonction du temps (durant le Covid)")
plt.xlabel("dates")
plt.ylabel("nombre de patients")
plt.show();
